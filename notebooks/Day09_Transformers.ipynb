# %%
import re

def tokenize(text):
    return re.findall(r"[A-Za-z]+(?:'[A-Za-z]+)?|[0-9]+|[^\sA-Za-z0-9]", text)

# %%
tokenize("The cats weren't running at 3pm.")
['The', 'cats', "weren't", 'running', 'at', '3', 'pm', '.']
# Out:
# ['The', 'cats', "weren't", 'running', 'at', '3', 'pm', '.']

# %% [markdown]
# # USING NLTK

# %%
import nltk

# %%
nltk.download("punkt_tab")
nltk.download("wordnet")
nltk.download("averaged_perceptron_tagger_eng")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Jesilda\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Jesilda\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Jesilda\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag

# %%
text = "The cats were running."
tokens=word_tokenize(text)
stemmed_text=[PorterStemmer().stem(word) for word in tokens]

# %%
lemmatizer = WordNetLemmatizer()
tagged = pos_tag(tokens)

# %%
def nltk_pos_to_wordnet(tag):
    if tag.startswith("V"):
        return "v"
    if tag.startswith("J"):
        return "a"
    if tag.startswith("R"):
        return "r"
    return "n"

# %%
lemmatized_text=[lemmatizer.lemmatize(word,nltk_pos_to_wordnet(tag)) for word,tag in tagged]

# %%
print(lemmatized_text)
# Out:
# ['The', 'cat', 'be', 'run', '.']

# %% [markdown]
# # spacy

# %%
import spacy
nlp=spacy.load("en_core_web_sm")
doc=nlp("The cats were running.")
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)
# Out:
# The the DET DT det Xxx True True
# cats cat NOUN NNS nsubj xxxx True False
# were be AUX VBD aux xxxx True True
# running run VERB VBG ROOT xxxx True False
# . . PUNCT . punct . False False
